# %% [markdown]
# # Resolução
# Bloco de Respostas C.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('company_sales_data.csv')
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
# Exercício 1:

profitList = df['total_profit'].tolist()
monthList = df['month_number'].tolist()

df.plot(x = 'month_number', y = 'total_profit')

plt.title('Company profit per month')
plt.xlabel('Month Number')
plt.ylabel('Total profit')
plt.xticks(monthList)
plt.yticks(range(100000, 500001, 100000))
plt.legend().remove()
plt.show()

# %%
# Exercício 2:

profitList = df['total_profit'].tolist()
monthList = df['month_number'].tolist()

df.plot(x = 'month_number', y = 'total_profit', 
                          linestyle = '--', marker = 'o',
                          markerfacecolor='black', color = 'red',
                          linewidth = '3', label = 'Profit data of last year')

plt.title('Company Sales data of last year')
plt.xlabel('Month Number')
plt.ylabel('Profit in dollar')
plt.xticks(monthList)
plt.yticks(range(100000, 500001, 100000))
plt.legend(loc=4)
plt.show()

# %%
# Exercício 3:

monthList = df['month_number'].tolist()

df.plot(x = 'month_number', y = ['facecream','facewash','toothpaste',
                                 'bathingsoap','shampoo','moisturizer'],
       marker = 'o', linewidth = '3')

plt.title('Sales data')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.xticks(monthList)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.legend(loc=2)
plt.show()

# %%
# Exercício 4:

vendas_produtos = [df['facecream'].sum(), df['facewash'].sum(), 
                     df['toothpaste'].sum(), df['bathingsoap'].sum(),
                     df['shampoo'].sum(), df['moisturizer'].sum()]

labels = ['Face cream', 'Face wash', 'Tooth paste',
          'Bathing soap','Shampoo', 'Moisturizer']

plt.pie(pct_produtos, labels = labels, autopct='%1.01f%%')
plt.title('Sales data')
plt.legend(loc='center left', bbox_to_anchor=(1.3,0,0.5,1))
plt.show()
